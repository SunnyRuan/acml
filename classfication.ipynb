# %% [markdown]
# <a href="https://colab.research.google.com/github/SunnyRuan/acml/blob/main/classfication.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.datasets import load_iris
iris = load_iris()
df = pd.DataFrame(iris["data"],columns=iris["feature_names"])
df["ans"]=iris["target"]
df.to_csv("iris.csv",encoding="utf-8",index=False)
#printdata
df

# %%
#sklearn前: pandas sklearn後:np.array
import numpy as np
from sklearn.model_selection import train_test_split
x = np.array(df.drop(["ans"],axis=1))
y = np.array(df["ans"])
#x_train,x_test,y_train,y_test = train_test_split([2,5,1,4],[1,3,6,9],test_size=0.1)
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1)
#printdata
x_train

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
clf.fit(x_train,y_train)

# %%
import graphviz
from sklearn.tree import export_graphviz
g = export_graphviz(clf,
            feature_names=iris["feature_names"],
            class_names=iris["target_names"],
            filled=True)
graphviz.Source(g)
